# %%
import pandas as pd

# %%
import os

# %%
def extract_results(base_dir):
    all = []
    for item in filter(lambda x: x.endswith(".tsv"), os.listdir(base_dir)):
        all.append(pd.read_csv(os.path.join(base_dir, item), sep="\t"))
    all_df = pd.concat(all)
    return all_df

# %%
all_df = extract_results("../results_and_log_cocondenser/log_codec_cocondenser/")

# %%
all_df.sort_values(["codec_type", "permutation"])[["codec_type", "permutation", 'component_memory_bytes', "avg_time_per_query_us", "avg_time_per_document_ns"]]
# Out:
#   codec_type      permutation  component_memory_bytes  avg_time_per_query_us  \
# 0      Delta  graph_bisection              1175379728            22224560.69
# 0      Delta            metis              1338985520            22515215.87
# 0      Delta             none              1517261000            22672804.22
# 0      Gamma  graph_bisection              1226107448            22044998.83
# 0      Gamma            metis              1432353816            22234286.53
# 0      Gamma             none              1665027976            22653649.39
# 0    VByteBe  graph_bisection              1294946944            18437210.81
# 0    VByteBe            metis              1336822968            19445965.30
# 0    VByteBe             none              1586370240            23144627.21
# 0    VByteLe  graph_bisection              1294946944            19013403.91
# 0    VByteLe            metis              1336822968            19943834.99
# 0    VByteLe             none              1586370240            23637283.68
# 0       Zeta  graph_bisection              1048669616            18508857.32
# 0       Zeta            metis              1187750904            19410095.30
# 0       Zeta             none              1341276304            20103059.85
#
#    avg_time_per_document_ns
# 0                  2513.572
# 0                  2546.445
# 0                  2564.268
# 0                  2493.264
# 0                  2514.672
# 0                  2562.102
# 0                  2085.227
# 0                  2199.316
# 0                  2617.631
# 0                  2150.394
# 0                  2255.625
# 0                  2673.350
# 0                  2093.330
# 0                  2195.259
# 0                  2273.633

# %%
assert len(pd.unique(all_df['compressed_memory_bytes'] - all_df['component_memory_bytes'])) == 1
values_mem_bytes = pd.unique(all_df['compressed_memory_bytes'] - all_df['component_memory_bytes'])[0]

# %%
log_partitioned_df = extract_results("../results_and_log_cocondenser/log_baseline_stremvbyte_cocondenser/")

# %%
log_partitioned_df
# Out:
#                                         dataset_name      permutation  \
# 0  /data2/knn_datasets/sparse_datasets/msmarco_v1...             none
# 0  /data2/knn_datasets/sparse_datasets/msmarco_v1...            metis
# 0  /data2/knn_datasets/sparse_datasets/msmarco_v1...  graph_bisection
#
#    num_documents  num_dimensions   total_nnz  avg_components_per_doc  \
# 0        8841823           28679  1060698636                  119.96
# 0        8841823           28679  1060698636                  119.96
# 0        8841823           28679  1060698636                  119.96
#
#    original_memory_bytes  compressed_memory_bytes  component_memory_bytes  \
# 0             8589934672               3886574516              1694442612
# 0             8589934672               3735811736              1543679832
# 0             8589934672               3712993374              1520861470
#
#    compression_ratio  num_queries  k_results  total_search_time_us  \
# 0           2.210156          100         10            348828.299
# 0           2.299349          100         10            346532.604
# 0           2.313480          100         10            356757.455
#
#    avg_time_per_query_us  avg_time_per_document_ns
# 0             3488282.99                   394.521
# 0             3465326.04                   391.924
# 0             3567574.54                   403.489

# %%
log_partitioned_df['component_memory_bytes'] = log_partitioned_df['compressed_memory_bytes'] - values_mem_bytes

# %%
1694442612 / 1024**2
# Out:
# 1615.9463996887207

# %%
log_partitioned_df['component_memory_bytes']
# Out:
# 0    1694442612
# 0    1543679832
# 0    1520861470
# Name: component_memory_bytes, dtype: int64

# %%
extract_results("../results_and_log_cocondenser/log_partitioned_cocondenser/")
# Out:
#                                         dataset_name permutation_strategy  \
# 0  /data2/knn_datasets/sparse_datasets/msmarco_v1...                  NaN
# 0  /data2/knn_datasets/sparse_datasets/msmarco_v1...                Metis
# 0  /data2/knn_datasets/sparse_datasets/msmarco_v1...       GraphBisection
#
#    n_partitions  n_component_bits  num_documents  num_dimensions   total_nnz  \
# 0           128                 8        8841823           28679  1060698636
# 0           128                 8        8841823           28679  1060698636
# 0           128                 8        8841823           28679  1060698636
#
#    avg_components_per_doc  original_memory_bytes  compressed_memory_bytes  \
# 0                  119.96             8589934672               3983405094
# 0                  119.96             8589934672               3707244174
# 0                  119.96             8589934672               3700201030
#
#    component_memory_bytes  compression_ratio  num_queries  k_results  \
# 0                       0           2.156430          100         10
# 0                       0           2.317067          100         10
# 0                       0           2.321478          100         10
#
#    total_search_time_ms  avg_time_per_query_ms  avg_time_per_document_ns
# 0            200349.251             2003492.51                   226.593
# 0            122421.478             1224214.77                   138.457
# 0            125239.185             1252391.84                   141.644

# %%
3700201030 / 1024**2
# Out:
# 3528.786687850952

# %%
4531762589 / 1024**3 - 2646522062 / 1024**3
# Out:
# 1.7557670613750815

# %%
# Out:
# 2.464765740558505
